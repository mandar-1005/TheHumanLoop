# %%
# @title Step 0: Setup and Installation
# Install ADK and LiteLLM for multi-model support

# !pip install google-adk -q
# !pip install litellm -q

print("Installation complete.")
# Out:
# WARNING: You are using pip version 21.2.3; however, version 26.0.1 is available.
# You should consider upgrading via the 'C:\Users\lspeh\TheHumanLoop\.venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Installation complete.
# WARNING: You are using pip version 21.2.3; however, version 26.0.1 is available.
# You should consider upgrading via the 'C:\Users\lspeh\TheHumanLoop\.venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# @title Import necessary libraries
import os
import asyncio
from google.adk.agents import Agent
from google.adk.models.lite_llm import LiteLlm # For multi-model support
from google.adk.sessions import InMemorySessionService
from google.adk.runners import Runner
from google.genai import types # For creating message Content/Parts

import warnings
# Ignore all warnings
warnings.filterwarnings("ignore")

import logging
logging.basicConfig(level=logging.ERROR)

print("Libraries imported.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       2 import os
#       3 import asyncio
# ----> 4 from google.adk.agents import Agent
#       5 from google.adk.models.lite_llm import LiteLlm # For multi-model support
#       6 from google.adk.sessions import InMemorySessionService
#
# File c:\Users\lspeh\TheHumanLoop\.venv\lib\site-packages\google\adk\__init__.py:18
#      15 from __future__ import annotations
#      17 from . import version
# ---> 18 from .agents.llm_agent import Agent
#      19 from .runners import Runner
#      21 __version__ = version.__version__
#
# File c:\Users\lspeh\TheHumanLoop\.venv\lib\site-packages\google\adk\agents\__init__.py:22
#      20 from .llm_agent import LlmAgent
#      21 from .loop_agent import LoopAgent
# ---> 22 from .mcp_instruction_provider import McpInstructionProvider
#      23 from .parallel_agent import ParallelAgent
#      24 from .run_config import RunConfig
#
# File c:\Users\lspeh\TheHumanLoop\.venv\lib\site-packages\google\adk\agents\mcp_instruction_provider.py:25
#      22 from typing import Dict
#      23 from typing import TextIO
# ---> 25 from mcp import types
#      27 from ..tools.mcp_tool.mcp_session_manager import MCPSessionManager
#      28 from .llm_agent import InstructionProvider
#
# File c:\Users\lspeh\TheHumanLoop\.venv\lib\site-packages\mcp\__init__.py:2
#       1 from .client.session import ClientSession
# ----> 2 from .client.session_group import ClientSessionGroup
#       3 from .client.stdio import StdioServerParameters, stdio_client
#       4 from .server.session import ServerSession
#
# File c:\Users\lspeh\TheHumanLoop\.venv\lib\site-packages\mcp\client\session_group.py:28
#      26 from mcp.client.session import ElicitationFnT, ListRootsFnT, LoggingFnT, MessageHandlerFnT, SamplingFnT
#      27 from mcp.client.sse import sse_client
# ---> 28 from mcp.client.stdio import StdioServerParameters
#      29 from mcp.client.streamable_http import streamable_http_client
#      30 from mcp.shared._httpx_utils import create_mcp_http_client
#
# File c:\Users\lspeh\TheHumanLoop\.venv\lib\site-packages\mcp\client\stdio\__init__.py:17
#      15 import mcp.types as types
#      16 from mcp.os.posix.utilities import terminate_posix_process_tree
# ---> 17 from mcp.os.win32.utilities import (
#      18     FallbackProcess,
#      19     create_windows_process,
#      20     get_windows_executable_command,
#      21     terminate_windows_process_tree,
#      22 )
#      23 from mcp.shared.message import SessionMessage
#      25 logger = logging.getLogger(__name__)
#
# File c:\Users\lspeh\TheHumanLoop\.venv\lib\site-packages\mcp\os\win32\utilities.py:22
#      20 # Windows-specific imports for Job Objects
#      21 if sys.platform == "win32":
# ---> 22     import pywintypes
#      23     import win32api
#      24     import win32con
#
# ModuleNotFoundError: No module named 'pywintypes'
